# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
reduce = [10,20,30,40,50,60,70,80,90,95,99,99.8]
metro = [1,10,50]
plt.figure(figsize=(12,6))
data = pd.read_csv("mnist_edge5_SA/performance_under_different_M/acc_untrained.csv")
plt.plot(reduce,data.mean()[2:None],'o-',label='SA')
for m in metro:
    data = pd.read_csv("mnist_edge5_SQA/performance_under_different_M/metropolis_{}/acc_untrained.csv".format(m))
    plt.plot(reduce,data.mean()[2:None],'o-',label='SQA(M={})'.format(m))
plt.legend()
plt.xticks(reduce[0:-1])
plt.grid(color='grey', linestyle='--', linewidth= 0.5 )
plt.xlabel('Pruned Ratio')
plt.ylabel('Accuracy')
# plt.savefig('mnist_edge5_acc_untrained_large_network.pdf')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
reduce = [10,20,30,40,50,60,70,80,90,95,99,99.8]
metro = [1,10,50]
plt.figure(figsize=(12,6))
data = pd.read_csv("mnist_edge5_SA/performance_under_different_M/acc_trained.csv")
plt.plot(reduce,data.mean()[2:None],'o-',label='SA')
for m in metro:
    data = pd.read_csv("mnist_edge5_SQA/performance_under_different_M/metropolis_{}/acc_trained.csv".format(m))
    plt.plot(reduce,data.mean()[2:None],'o-',label='SQA(M={})'.format(m))
plt.legend()
plt.xticks(reduce[0:-1])
plt.grid(color='grey', linestyle='--', linewidth= 0.5 )
plt.xlabel('Pruned Ratio')
plt.ylabel('Accuracy')
# plt.savefig('mnist_edge5_acc_untrained_large_network.pdf')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
reduce = [10,20,30,40,50,60,70,80,90,95,99]
metro = [1,10,50]
plt.figure(figsize=(12,6))
data = pd.read_csv("mnist_edge5_SA/performance_under_different_M/acc_untrained.csv")
plt.plot(reduce,data.mean()[2:-1],'o-',label='SA')
for m in metro:
    data = pd.read_csv("mnist_edge5_SQA/performance_under_different_M/metropolis_{}/acc_untrained.csv".format(m))
    plt.plot(reduce,data.mean()[2:-1],'o-',label='SQA(M={})'.format(m))
    
    data = pd.read_csv("mnist_edge5_SQA_based_minK/performance_under_different_M/metropolis_{}/acc_untrained.csv".format(m))
    plt.plot(reduce,data.mean()[2:None],'o-',label='SQA_based_minK(M={})'.format(m))
plt.legend()
plt.xticks(reduce[0:-1])
plt.grid(color='grey', linestyle='--', linewidth= 0.5 )
plt.xlabel('Pruned Ratio')
plt.ylabel('Accuracy')
# plt.savefig('mnist_edge5_acc_untrained_large_network.pdf')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
reduce = [10,20,30,40,50,60,70,80,90,95,99]
metro = [1,10,50]
plt.figure(figsize=(12,6))
data = pd.read_csv("mnist_edge5_SA/performance_under_different_M/acc_trained.csv")
plt.plot(reduce,data.mean()[2:-1],'o-',label='SA')
for m in metro:
    data = pd.read_csv("mnist_edge5_SQA/performance_under_different_M/metropolis_{}/acc_trained.csv".format(m))
    plt.plot(reduce,data.mean()[2:-1],'o-',label='SQA(M={})'.format(m))
    
    data = pd.read_csv("mnist_edge5_SQA_based_minK/performance_under_different_M/metropolis_{}/acc_trained.csv".format(m))
    plt.plot(reduce,data.mean()[2:None],'o-',label='SQA_based_minK(M={})'.format(m))
plt.legend()
plt.xticks(reduce[0:-1])
plt.grid(color='grey', linestyle='--', linewidth= 0.5 )
plt.xlabel('Pruned Ratio')
plt.ylabel('Accuracy')
# plt.savefig('mnist_edge5_acc_untrained_large_network.pdf')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
reduce = [10,20,30,40,50,60,70,80,90,95,99,99.8]
metro = [1,10,50]
plt.figure(figsize=(12,6))
data = pd.read_csv("fashion_edge5_SA/performance_under_different_M/acc_trained.csv")
plt.plot(reduce,data.mean()[2:None],'o-',label='SA')
for m in metro:
    data = pd.read_csv("fashion_edge5_SQA/performance_under_different_M/metropolis_{}/acc_trained.csv".format(m))
    plt.plot(reduce,data.mean()[2:None],'o-',label='SQA(M={})'.format(m))
plt.legend()
plt.xticks(reduce[0:-1])
plt.grid(color='grey', linestyle='--', linewidth= 0.5 )
plt.xlabel('Pruned Ratio')
plt.ylabel('Accuracy')
plt.savefig('mnist_edge5_acc_trained_large_network.pdf')
